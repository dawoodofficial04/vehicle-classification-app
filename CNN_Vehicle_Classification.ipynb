# %% [markdown]
# # Convolutionary Neural Network Model for Vehicle Classification

# %% [markdown]
# 1.  A CNN scans the image in small patches (filters) to detect simple patterns first — edges, colors, and textures.
#
# 2. Each layer stacks on the previous one, combining simple patterns into more complex shapes — wheels, windows, wings — the deeper you go.
#
# 3. At the end, it takes all these learned features and votes on which class (car, bus, bicycle, etc.) they most likely belong to.

# %%
# %pip install tensorflow kagglehub pillow matplotlib
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.12/dist-packages (2.20.0)
# Requirement already satisfied: kagglehub in /usr/local/lib/python3.12/dist-packages (1.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (3.10.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (25.12.19)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.7.0)
# Requirement already satisfied: google_pasta>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt_einsum>=2.3.2 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from tensorflow) (26.2)
# Requirement already satisfied: protobuf>=5.28.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (5.29.6)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.32.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: typing_extensions>=3.6.6 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (4.16.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.2.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (1.82.1)
# Requirement already satisfied: tensorboard~=2.20.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.20.0)
# Requirement already satisfied: keras>=3.10.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.13.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (3.16.0)
# Requirement already satisfied: ml_dtypes<1.0.0,>=0.5.1 in /usr/local/lib/python3.12/dist-packages (from tensorflow) (0.5.4)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.22 in /usr/local/lib/python3.12/dist-packages (from kagglehub) (0.1.23)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from kagglehub) (6.0.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from kagglehub) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (4.63.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (1.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from astunparse>=1.6.0->tensorflow) (0.47.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras>=3.10.0->tensorflow) (0.19.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.9)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.18)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.21.0->tensorflow) (2026.6.17)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.10.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from tensorboard~=2.20.0->tensorflow) (3.1.8)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from werkzeug>=1.0.1->tensorboard~=2.20.0->tensorflow) (3.0.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras>=3.10.0->tensorflow) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.10.0->tensorflow) (0.1.2)

# %% [markdown]
# ## Dataset Link from Kaggle
#
# https://www.kaggle.com/datasets/mmohaiminulislam/vehicles-image-dataset

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mmohaiminulislam/vehicles-image-dataset")

print("Path to dataset files:", path)
# Out:
# Downloading to /root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/1.archive...
# 100%|██████████| 1.64G/1.64G [00:26<00:00, 67.7MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1

# %%
import os

# Show files
for root, dirs, files in os.walk(path):
    print(root)
    print(dirs[:5])
    break
# Out:
# /root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1
# ['vehicle_data']

# %%
# %ls "{path}/vehicle_data/"
# Out:
# airplane/   boat/  fire_truck/  jet_ski/     rickshaw/  skateboard/  unicycle/
# ambulance/  bus/   helicopter/  kayak/       scooter/   tractor/     van/
# bicycle/    car/   hovercraft/  motorcycle/  segway/    truck/

# %%
# %pip install split-folders
# Out:
# Collecting split-folders
#   Downloading split_folders-0.6.1-py3-none-any.whl.metadata (11 kB)
# Downloading split_folders-0.6.1-py3-none-any.whl (13 kB)
# Installing collected packages: split-folders
# Successfully installed split-folders-0.6.1

# %%
import splitfolders
import os

# %%
input_folder = os.path.join(path, "vehicle_data")
output_folder = os.path.join(path, "split_dataset")

# %% [markdown]
# ## Splitting Dataset in 80% Trainuing, 10% Testing, 10% Validation

# %%
splitfolders.ratio(
    input=input_folder,
    output=output_folder,
    seed=42,
    ratio=(0.8, 0.1, 0.1),
    group_prefix=None,
    move=False
)
# Out:
# Copying files: 3698 files [00:30, 119.56 files/s]

# %% [markdown]
# Converting 4 Channel to 3 Channels

# %%
from PIL import Image
import os

dataset_dir = output_folder

bad = []

for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        if file.lower().endswith((".jpg", ".jpeg", ".png", ".bmp", ".gif", ".webp")):
            p = os.path.join(root, file)

            try:
                img = Image.open(p)
                if img.mode != "RGB":
                    bad.append((p, img.mode))
            except Exception as e:
                bad.append((p, str(e)))

print("Bad Images:", len(bad))

for b in bad[:50]:
    print(b)
# Out:
# Bad Images: 311
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/ambulance/237055ef-a46e-46bc-a1fc-4490681f5e0b.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/tractor/4d62c774-2f39-4b09-87f2-c0a9360fbd1b.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/tractor/85e54584-8bf7-4e8f-b2ca-ffe39dd3a189.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/tractor/bb8f3774-8bf7-4375-ad6e-d8f601f3e334.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/unicycle/b08ce92d-f6bd-4b79-934e-7568bdfeaee8.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/unicycle/11c121ef-f1f0-4dbc-a257-cfc43bb62277.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/unicycle/e7c68487-94ec-411c-94f8-9e66cc712923.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/bicycle/25c16813-1491-4f67-a3b6-8d4c8976e153.jpg', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/bicycle/2553bb55-1467-4b92-ade8-a532eb8342fd.jpg', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/bicycle/546e0d7a-c6b5-4e07-b12e-ec32159078e3.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/jet_ski/5de44b08-0720-40d3-9a6c-b9613e184399.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/segway/53b6a977-4d69-40f7-ac96-9bc8772359cb.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/segway/ccb8556f-3590-48d4-bedc-61370a9e87ae.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/motorcycle/33a78053-0cee-44eb-91fe-ad36f24ba23a.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/0b8aaf2e-b93b-48fc-8ca2-0917f43f37fc.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/2f882b1b-2272-47e7-a987-8023cfc5f73e.gif', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/2c96ce5d-f71a-482d-9c2b-79be4b3d4599.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/712e89a8-3600-4545-8602-6ae05fb6e4b2.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/airplane/0f250e66-49d6-4e58-9e61-78fdc9760235.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/car/262bf213-7d8d-4450-ba5a-1beb1a0d5456.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/car/2bba24bb-ebf2-4bbf-a25e-87e7e8c07dbc.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/car/c332d5b9-1e4d-4274-aac6-3f25318ec447.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/car/e1b5ab71-09ff-42ec-83b8-b7de2f61875c.jpg', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/scooter/2a5d85b5-0961-4348-910e-8042f31fceb9.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/scooter/c16ba4d0-19ef-4f49-92af-2d005e47ad61.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/scooter/481ddc1c-772b-4ff9-bfb8-bc1e32f0defc.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/rickshaw/51fa7906-487a-44cc-b9d1-d9c24daba6c2.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/skateboard/38f16016-6c58-4e5e-abcf-b4b951106cdf.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/skateboard/dc1e9500-4664-4aa0-a88c-18758e9dfc38.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/skateboard/bc9fa37a-83b1-4719-ad42-4e5a2180fb70.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/skateboard/6450f9d3-2e8c-4128-8eff-2eb00428c7d8.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/truck/5cc58253-2043-4f22-89ac-a18ea4772aa4.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/helicopter/e71c840c-0b96-4bba-94a1-25edfba66f01.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/test/helicopter/20f87069-ea1b-4721-8ff6-506f71b3198d.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/ambulance/ee3019be-b7e7-4bfe-b1c1-aac7df78e88d.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/ambulance/ed49182c-32a8-41f5-9f1a-a1efc965e241.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/tractor/025a5dc8-6322-49c4-8ec7-16636b76607b.jpg', 'L')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/tractor/f28e479e-bc56-4d15-bb2d-05884e0e7af1.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/tractor/6ee023e8-11fc-4009-b1c2-68c8b2e7082e.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/fabe8966-b8e1-41c4-a59c-c5d8ece2edec.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/ed1fdf68-cc9f-4be6-a0ab-619a3f5b6210.png', 'P')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/7f57d365-467e-4c25-98fb-bc28cf6ce83f.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/unicycle/cb29519c-76b3-49d0-a05e-5c6748cb15ab.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/bicycle/3d2980a8-a404-412d-b599-895dc1f96e55.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/bicycle/3d28ee7b-f3f4-4b98-9099-1ff806fddd68.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/van/f436090a-9a9e-4253-a90e-0aafd2d858d8.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/fire_truck/d5583536-b3d5-4479-bdb4-97694f7dfb8e.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/fire_truck/3f841eaa-f2f7-4e46-809e-265510af42e9.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/fire_truck/6b5af22c-a330-4783-9f94-55c3ddcdf173.png', 'RGBA')
# ('/root/.cache/kagglehub/datasets/mmohaiminulislam/vehicles-image-dataset/versions/1/split_dataset/val/motorcycle/fc8e4fcf-0a8a-4eca-8a65-44f3a01d87f8.png', 'RGBA')

# %%
from PIL import Image
import os

dataset_dir = os.path.join(path, "split_dataset")

converted = 0
failed = []

for root, dirs, files in os.walk(dataset_dir):
    for file in files:
        if file.lower().endswith((".png", ".jpg", ".jpeg", ".bmp", ".webp")):
            img_path = os.path.join(root, file)

            try:
                img = Image.open(img_path)

                # Convert every non-RGB image
                if img.mode != "RGB":
                    img = img.convert("RGB")
                    img.save(img_path)
                    converted += 1

            except Exception as e:
                failed.append((img_path, str(e)))

print(f"Converted: {converted}")
print(f"Failed: {len(failed)}")

if failed:
    print(failed[:10])
# Out:
# /usr/local/lib/python3.12/dist-packages/PIL/Image.py:1047: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Converted: 299
# Failed: 0

# %%
for folder in ["train", "val", "test"]:
    print(f"\n{folder.upper()}")
    print(os.listdir(os.path.join(output_folder, folder))[:5])
# Out:
# TRAIN
# ['ambulance', 'tractor', 'unicycle', 'bicycle', 'kayak']
#
# VAL
# ['ambulance', 'tractor', 'unicycle', 'bicycle', 'kayak']
#
# TEST
# ['ambulance', 'tractor', 'unicycle', 'bicycle', 'kayak']

# %%
train_dir = os.path.join(output_folder, "train")
val_dir = os.path.join(output_folder, "val")
test_dir = os.path.join(output_folder, "test")

# %%
import os
import tensorflow as tf

IMG_SIZE = (128, 128)
BATCH_SIZE = 32


train_ds = tf.keras.utils.image_dataset_from_directory(
    train_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=True,
    seed=42
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    val_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

test_ds = tf.keras.utils.image_dataset_from_directory(
    test_dir,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE,
    shuffle=False
)

class_names = train_ds.class_names

AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().shuffle(1000).prefetch(AUTOTUNE)
val_ds = val_ds.cache().prefetch(AUTOTUNE)
test_ds = test_ds.cache().prefetch(AUTOTUNE)

print("Number of Classes:", len(class_names))
print("Classes:", class_names)
# Out:
# Found 2946 files belonging to 20 classes.
# Found 362 files belonging to 20 classes.
# Found 384 files belonging to 20 classes.
# Number of Classes: 20
# Classes: ['airplane', 'ambulance', 'bicycle', 'boat', 'bus', 'car', 'fire_truck', 'helicopter', 'hovercraft', 'jet_ski', 'kayak', 'motorcycle', 'rickshaw', 'scooter', 'segway', 'skateboard', 'tractor', 'truck', 'unicycle', 'van']

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input, Conv2D, MaxPooling2D, BatchNormalization,
    GlobalAveragePooling2D, Dense, Dropout, Rescaling,
    RandomFlip, RandomRotation, RandomZoom, RandomContrast,
    RandomTranslation
)
from tensorflow.keras.regularizers import l2

num_classes = len(class_names)


model = Sequential([
    Input(shape=(128, 128, 3)),

    # Augmentation
    RandomFlip("horizontal"),
    RandomRotation(0.1),
    RandomZoom(0.1),

    Rescaling(1./255),

    # Block 1
    Conv2D(32, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.2),

    # Block 2
    Conv2D(64, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.25),

    # Block 3
    Conv2D(128, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.3),

    # Block 4
    Conv2D(256, (3,3), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling2D(),
    Dropout(0.35),

    GlobalAveragePooling2D(),

    Dense(128, activation='relu'),
    Dropout(0.5),

    Dense(num_classes, activation='softmax')
])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ random_flip (RandomFlip)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_rotation                 │ (None, 128, 128, 3)    │             0 │
# │ (RandomRotation)                │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ random_zoom (RandomZoom)        │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ rescaling (Rescaling)           │ (None, 128, 128, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 128, 128, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 128, 128, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 64, 64, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 64, 64, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 32, 32, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 32, 32, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 32, 32, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 16, 16, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 16, 16, 256)    │       295,168 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 16, 16, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 8, 8, 256)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 256)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │         2,580 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 425,812 (1.62 MB)
#  Trainable params: 424,852 (1.62 MB)
#  Non-trainable params: 960 (3.75 KB)

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data=test_ds,
    epochs=80
)
# Out:
# Epoch 1/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 334s 3s/step - accuracy: 0.1045 - loss: 3.0162 - val_accuracy: 0.0495 - val_loss: 4.4783
# Epoch 2/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 266s 2s/step - accuracy: 0.1402 - loss: 2.8078 - val_accuracy: 0.0521 - val_loss: 5.7507
# Epoch 3/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.1752 - loss: 2.7169 - val_accuracy: 0.0495 - val_loss: 5.4169
# Epoch 4/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 253s 2s/step - accuracy: 0.1819 - loss: 2.6498 - val_accuracy: 0.0625 - val_loss: 5.1988
# Epoch 5/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 224s 2s/step - accuracy: 0.1976 - loss: 2.6089 - val_accuracy: 0.0755 - val_loss: 4.0264
# Epoch 6/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 259s 2s/step - accuracy: 0.2088 - loss: 2.5232 - val_accuracy: 0.1432 - val_loss: 2.6783
# Epoch 7/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 214s 2s/step - accuracy: 0.2318 - loss: 2.4715 - val_accuracy: 0.2057 - val_loss: 2.4797
# Epoch 8/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 271s 2s/step - accuracy: 0.2539 - loss: 2.4241 - val_accuracy: 0.2161 - val_loss: 2.4487
# Epoch 9/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 217s 2s/step - accuracy: 0.2665 - loss: 2.3615 - val_accuracy: 0.2240 - val_loss: 2.3877
# Epoch 10/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 226s 2s/step - accuracy: 0.2780 - loss: 2.3261 - val_accuracy: 0.1719 - val_loss: 2.7300
# Epoch 11/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 287s 3s/step - accuracy: 0.2960 - loss: 2.2528 - val_accuracy: 0.2318 - val_loss: 2.3795
# Epoch 12/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 252s 3s/step - accuracy: 0.3150 - loss: 2.2288 - val_accuracy: 0.3099 - val_loss: 2.1629
# Epoch 13/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 266s 3s/step - accuracy: 0.3269 - loss: 2.1749 - val_accuracy: 0.2839 - val_loss: 2.2183
# Epoch 14/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 254s 3s/step - accuracy: 0.3394 - loss: 2.1329 - val_accuracy: 0.3151 - val_loss: 2.2917
# Epoch 15/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 274s 3s/step - accuracy: 0.3493 - loss: 2.0897 - val_accuracy: 0.2734 - val_loss: 2.3448
# Epoch 16/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 255s 3s/step - accuracy: 0.3581 - loss: 2.0294 - val_accuracy: 0.3125 - val_loss: 2.1562
# Epoch 17/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 267s 3s/step - accuracy: 0.3578 - loss: 2.0527 - val_accuracy: 0.2396 - val_loss: 2.4537
# Epoch 18/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 250s 3s/step - accuracy: 0.3870 - loss: 1.9643 - val_accuracy: 0.3229 - val_loss: 2.3431
# Epoch 19/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 248s 3s/step - accuracy: 0.3832 - loss: 1.9424 - val_accuracy: 0.3880 - val_loss: 1.8799
# Epoch 20/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 264s 3s/step - accuracy: 0.3982 - loss: 1.9298 - val_accuracy: 0.3151 - val_loss: 2.2163
# Epoch 21/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 250s 3s/step - accuracy: 0.4124 - loss: 1.8626 - val_accuracy: 0.3333 - val_loss: 2.1748
# Epoch 22/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 262s 3s/step - accuracy: 0
80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.6582 - loss: 1.0403 - val_accuracy: 0.4531 - val_loss: 2.1552
# Epoch 56/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - accuracy: 0.6551 - loss: 1.0633 - val_accuracy: 0.4115 - val_loss: 2.3155
# Epoch 57/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.6511 - loss: 1.0663 - val_accuracy: 0.4271 - val_loss: 2.0530
# Epoch 58/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.6602 - loss: 1.0401 - val_accuracy: 0.3880 - val_loss: 2.3939
# Epoch 59/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 263s 2s/step - accuracy: 0.6768 - loss: 1.0277 - val_accuracy: 0.3203 - val_loss: 2.8288
# Epoch 60/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - accuracy: 0.6813 - loss: 0.9745 - val_accuracy: 0.4766 - val_loss: 1.9903
# Epoch 61/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 262s 2s/step - accuracy: 0.6775 - loss: 1.0015 - val_accuracy: 0.3568 - val_loss: 2.7405
# Epoch 62/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 214s 2s/step - accuracy: 0.6908 - loss: 0.9438 - val_accuracy: 0.4089 - val_loss: 2.6941
# Epoch 63/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 215s 2s/step - accuracy: 0.6877 - loss: 0.9492 - val_accuracy: 0.4688 - val_loss: 2.1634
# Epoch 64/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 0.6986 - loss: 0.9319 - val_accuracy: 0.4505 - val_loss: 2.1366
# Epoch 65/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.7060 - loss: 0.9043 - val_accuracy: 0.4427 - val_loss: 2.1375
# Epoch 66/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.7013 - loss: 0.9141 - val_accuracy: 0.4427 - val_loss: 2.5185
# Epoch 67/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - accuracy: 0.7030 - loss: 0.9104 - val_accuracy: 0.4479 - val_loss: 2.2147
# Epoch 68/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 264s 2s/step - accuracy: 0.7111 - loss: 0.8563 - val_accuracy: 0.4349 - val_loss: 2.3264
# Epoch 69/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - accuracy: 0.7043 - loss: 0.8988 - val_accuracy: 0.4479 - val_loss: 2.4476
# Epoch 70/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 212s 2s/step - accuracy: 0.7081 - loss: 0.8817 - val_accuracy: 0.4115 - val_loss: 2.4058
# Epoch 71/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.7186 - loss: 0.8636 - val_accuracy: 0.4531 - val_loss: 2.3148
# Epoch 72/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 211s 2s/step - accuracy: 0.7206 - loss: 0.8429 - val_accuracy: 0.4271 - val_loss: 2.4852
# Epoch 73/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 212s 2s/step - accuracy: 0.7179 - loss: 0.8388 - val_accuracy: 0.4740 - val_loss: 2.1387
# Epoch 74/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 269s 2s/step - accuracy: 0.7298 - loss: 0.8207 - val_accuracy: 0.4661 - val_loss: 2.1499
# Epoch 75/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 213s 2s/step - accuracy: 0.7376 - loss: 0.7768 - val_accuracy: 0.4688 - val_loss: 2.2922
# Epoch 76/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 219s 2s/step - accuracy: 0.7244 - loss: 0.8410 - val_accuracy: 0.4531 - val_loss: 2.4030
# Epoch 77/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 216s 2s/step - accuracy: 0.7162 - loss: 0.8184 - val_accuracy: 0.4115 - val_loss: 2.8255
# Epoch 78/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 216s 2s/step - accuracy: 0.7451 - loss: 0.7947 - val_accuracy: 0.4531 - val_loss: 2.6861
# Epoch 79/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 216s 2s/step - accuracy: 0.7461 - loss: 0.7566 - val_accuracy: 0.4844 - val_loss: 2.0230
# Epoch 80/80
# 93/93 ━━━━━━━━━━━━━━━━━━━━ 221s 2s/step - accuracy: 0.7379 - loss: 0.7907 - val_accuracy: 0.4714 - val_loss: 2.2242

# %%
loss, accuracy = model.evaluate(test_ds)

print(f"Test Loss: {loss:.4f}")
print(f"Test Accuracy: {accuracy:.4f}")
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 5s 436ms/step - accuracy: 0.4714 - loss: 2.2242
# Test Loss: 2.2242
# Test Accuracy: 0.4714

# %%
model.save("cars_cnn.keras")

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

def predict_image(img_path, model, class_names, img_size=128):
    # Load and resize image
    img = image.load_img(img_path, target_size=(img_size, img_size))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = np.max(predictions[0]) * 100

    # Show image with prediction
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_class} ({confidence:.2f}%)")
    plt.show()

    return predicted_class, confidence


# Usage
predict_image("bike.jpeg", model, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# ('motorcycle', np.float32(88.85028))

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

def predict_image(img_path, model, class_names, img_size=128):
    # Load and resize image
    img = image.load_img(img_path, target_size=(img_size, img_size))
    img_array = image.img_to_array(img)
    img_array = np.expand_dims(img_array, axis=0)

    # Predict
    predictions = model.predict(img_array)
    predicted_class = class_names[np.argmax(predictions[0])]
    confidence = np.max(predictions[0]) * 100

    # Show image with prediction
    plt.imshow(img)
    plt.axis('off')
    plt.title(f"Predicted: {predicted_class} ({confidence:.2f}%)")
    plt.show()

    return predicted_class, confidence


# Usage
predict_image("car.jpeg", model, class_names)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# ('car', np.float32(99.98342))
